# %%
from CalcWaterSteam1 import SteamCalc
steam = SteamCalc(s = 7.2, p = 0.006)

h = steam.find_h()
print("1. h:", h)

p_2,t_2,v_2 = steam.calculation_isoentropic_process(p_1 = 3, t_1 = 500, p_2 = 6)
print("2. p_2:", p_2)
print("3. v_2:", v_2)
print("4. t_2:", t_2)

s_nas = steam.find_s_s_po_p()
print("5. s_nas :", s_nas)
# Out:
# 1. h: 2217.411502387167
# 2. p_2: 6
# 3. v_2: 500.6314959310529
# 4. t_2: 0.0011996317247063499
# 5. s_nas : 8.329146455525182

# %%
from CalcIdealGas1 import GasCalc
gas = GasCalc(c_p = 1600, r = 8.31, t = 100, v = 2)

p = gas.calc_p()
print("1. p =", p)

t = gas.calc_t()
print("2. t =", t)

v = gas.calc_v() 
print("3. v =", v)

h = gas.calc_h() 
print("4. h =", h)

c_v = gas.calc_c_v()
print("5. c_v =", c_v)

gamma = gas.calc_gamma()
print("6. capacity_ratio =", gamma)

v_2, t_2, p = gas.calc_isobaric_process( v_1 = 20, t_1 = 30, t_2 = 10 )
print("7. v_2 =", v_2)
print("8. t_2 =", t_2)
print("9. p =", p)
# Out:
# 1. p = 415.5
# 2. t = 100
# 3. v = 2
# 4. h = 160000
# 5. c_v = 1591.69
# 6. capacity_ratio = 1.0052208658721233
# 7. v_2 = 12.465
# 8. t_2 = 10.358415
# 9. p = 10
